# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %%
data = pd.read_csv("train.csv")
df = data.drop("id", axis=1)
test_data = pd.read_csv("test.csv")

# %%
df
# Out:
#          brand                             model  model_year  milage  \
# 0         Ford                      F-150 Lariat        2018   74349
# 1          BMW                             335 i        2007   80000
# 2       Jaguar                         XF Luxury        2009   91491
# 3          BMW                      X7 xDrive40i        2022    2437
# 4      Pontiac                     Firebird Base        2001  111000
# ...        ...                               ...         ...     ...
# 54268      BMW                      X6 xDrive50i        2017   29000
# 54269     Audi                   A4 2.0T Premium        2015   94634
# 54270  Porsche                         Cayenne S        2013   40989
# 54271  Porsche                 911 Carrera 4 GTS        2023    1518
# 54272     Audi  A5 Sportback S line Premium Plus        2021   35000
#
#            fuel_type                                             engine  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54273 entries, 0 to 54272
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         54273 non-null  object
#  1   model         54273 non-null  object
#  2   model_year    54273 non-null  int64
#  3   milage        54273 non-null  int64
#  4   fuel_type     54273 non-null  object
#  5   engine        54273 non-null  object
#  6   transmission  54273 non-null  object
#  7   ext_col       54273 non-null  object
#  8   int_col       54273 non-null  object
#  9   accident      54273 non-null  object
#  10  clean_title   54273 non-null  object
#  11  price         54273 non-null  int64
# dtypes: int64(3), object(9)
# memory usage: 5.0+ MB

# %%
df.isnull().sum()
# Out:
# brand           0
# model           0
# model_year      0
# milage          0
# fuel_type       0
# engine          0
# transmission    0
# ext_col         0
# int_col         0
# accident        0
# clean_title     0
# price           0
# dtype: int64

# %%
objects = df.select_dtypes(include=["object"]).columns.tolist()
objects
# Out:
# ['brand',
#  'model',
#  'fuel_type',
#  'engine',
#  'transmission',
#  'ext_col',
#  'int_col',
#  'accident',
#  'clean_title']

# %%
for i in df.columns:
        df[i] = df[i].astype("category").cat.codes

# %%
df
# Out:
#        brand  model  model_year  milage  fuel_type  engine  transmission  \
# 0         14    644          27    2070          2     719             2
# 1          4     49          16    2187          2     534            18
# 2         21   1771          18    2376          2     541            14
# 3          4   1748          31     146          3     646            43
# 4         40    693          10    2632          2     219            34
# ...      ...    ...         ...     ...        ...     ...           ...
# 54268      4   1745          26    1062          2     856            27
# 54269      3    165          24    2424          1     266            14
# 54270     41    421          22    1372          2     817            43
# 54271     41    142          32      89          2     762            29
# 54272      3    176          30    1208          3     372            27
#
#        ext_col  int_col  accident  clean_title  price
# ...

# %%
df.corr()
# Out:
#                  brand     model  model_year    milage  fuel_type    engine  \
# brand         1.000000 -0.095992   -0.068646  0.038043   0.038529 -0.134387
# model        -0.095992  1.000000   -0.000303  0.050257   0.013908 -0.036810
# model_year   -0.068646 -0.000303    1.000000 -0.625517  -0.041952  0.302096
# milage        0.038043  0.050257   -0.625517  1.000000  -0.083994 -0.358953
# fuel_type     0.038529  0.013908   -0.041952 -0.083994   1.000000  0.053997
# engine       -0.134387 -0.036810    0.302096 -0.358953   0.053997  1.000000
# transmission  0.025874  0.003388    0.046601 -0.026079   0.094454 -0.008197
# ext_col       0.006090 -0.009944   -0.023204  0.020598  -0.017347 -0.037801
# int_col       0.000565  0.015077   -0.017930 -0.019937   0.015191 -0.015230
# accident     -0.012365 -0.024859    0.216556 -0.298897   0.031950  0.169916
# clean_title        NaN       NaN         NaN       NaN        NaN       NaN
# ...

# %%
dx = df.drop(["price", "fuel_type", "transmission", "int_col"], axis=1)
dy = df["price"]

# %%
model = RandomForestRegressor()
x_train, x_test, y_train, y_test = train_test_split(dx, dy, test_size=0.2)

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
model.score(x_test, y_test)
# Out:
# 0.6615840716252491

# %%
test_data
# Out:
#           id          brand  \
# 0      54273  Mercedes-Benz
# 1      54274          Lexus
# 2      54275  Mercedes-Benz
# 3      54276           Land
# 4      54277            BMW
# ...      ...            ...
# 36178  90451            GMC
# 36179  90452      Chevrolet
# 36180  90453         Toyota
# 36181  90454        Lincoln
# 36182  90455      Chevrolet
#
#                                                    model  model_year  milage  \
# 0                                          E-Class E 350        2014   73000
# 1                                            RX 350 Base        2015  128032
# 2                                          C-Class C 300        2015   51983
# 3      Rover Range Rover 5.0L Supercharged Autobiogra...        2018   29500
# 4                                           X6 xDrive40i        2020   90000
# ...                                                  ...         ...     ...
# 36178                                       Yukon Denali        2019    4500
# ...

# %%
test_data.isnull().sum()
# Out:
# id              0
# brand           0
# model           0
# model_year      0
# milage          0
# fuel_type       0
# engine          0
# transmission    0
# ext_col         0
# int_col         0
# accident        0
# clean_title     0
# dtype: int64

# %%
for i in test_data.columns:
        test_data[i] = test_data[i].astype("category").cat.codes

# %%
test_data.drop(["fuel_type", "transmission", "int_col", "id"], axis=1)
# Out:
#        brand  model  model_year  milage  engine  ext_col  accident  \
# 0         34    528          23    1887     544      220         1
# 1         26   1246          24    2570     410      187         1
# 2         34    317          24    1486     311       26         1
# 3         25   1318          27     979     911      220         0
# 4          4   1710          29    2164     633      220         0
# ...      ...    ...         ...     ...     ...      ...       ...
# 36178     15   1763          28     213     807       88         1
# 36179      9   1481          13    2856     473      163         0
# 36180     49    480          20    2460      30       12         1
# 36181     27   1082          28    1209     843       17         1
# 36182      9   1575          21    2784     601       17         0
#
#        clean_title
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# ...

# %%
model.predict
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[212], line 1
# ----> 1 model.predict(test_data)
#
# File c:\Users\91909\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\ensemble\_forest.py:1064, in ForestRegressor.predict(self, X)
#    1062 check_is_fitted(self)
#    1063 # Check data
# -> 1064 X = self._validate_X_predict(X)
#    1066 # Assign chunk of trees to jobs
#    1067 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File c:\Users\91909\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\ensemble\_forest.py:641, in BaseForest._validate_X_predict(self, X)
#     638 else:
#     639     force_all_finite = True
# --> 641 X = self._validate_data(
#     642     X,
#     643     dtype=DTYPE,
#     644     accept_sparse="csr",
#     645     reset=False,
#     646     force_all_finite=force_all_finite,
#     647 )
# ...
